# %% [markdown]
# # About
#
#     The objective of this challenge is to automate the process of estimating the soil parameters, specifically, potassium (K), phosphorus pentoxide (P2O5P_2O_5P2​O5​), magnesium (Mg) and pH, through extracting them from the airborne hyperspectral images captured over agricultural areas in Poland (the exact locations are not revealed). To make the solution applicable in real-life use cases, all the parameters should be estimated as precisely as possible.
#
#     The dataset comprises 2886 patches in total (2 m GSD), of which 1732 patches for training and 1154 patches for testing. The patch size varies (depending on agricultural parcels) and is on average around 60x60 pixels. Each patch contains 150 contiguous hyperspectral bands (462-942 nm, with a spectral resolution of 3.2 nm), which reflects the spectral range of the hyperspectral imaging sensor deployed on-board Intuition-1.
#
#     The participants are given a training set of 1732 training examples. The examples are hyperspectral image patches with the corresponding ground-truth information. Each masked patch corresponds to a field of interest, as presented in Fig. 1. Ground truth are the soil parameters obtained for the soil samples collected for each field of interest in the process of laboratory analysis, and is represented by a 4-value vector.

# %% [markdown]
# # References and Resources
#
# * Competition Page https://platform.ai4eo.eu/seeing-beyond-the-visible
# * Starter code :  https://github.com/AI4EO/kp-labs-seeing-beyond-visible-challenge/blob/main/starter_pack.ipynb

# %% [markdown]
# # Dataset
#
#     The Dataset consists of Training and test dataset folders. The train folder has traiing image tiles, along with the concentration of elements (target), while the test folder has only the test images.
#
#     The hyperspectral images consists of 150 bands (i.e 150 channels) ranging in wavelength from nm to nm . The task is to predict soil properties from these hyperspectral images.

# %% [markdown]
# # Imports

# %%
import sys 
import os
import pandas as pd
import numpy as np
import glob
import gc


from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from tqdm import tqdm
import multiprocessing as mp 

#plotting
import matplotlib.pyplot as plt 
import seaborn as sns
from termcolor import colored

import cv2
import tensorflow as tf 
import tensorflow.keras.backend as K




pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',50)



def  color_print(print_str,
                 print_color='green'):
    
    '''print in given  color (default green)'''
    print(colored(print_str,print_color))

# %%
class CFG:
    seed = 7
    img_size = (60,60)
    BATCH_SIZE = 32
    Autotune = tf.data.AUTOTUNE
    validation_size = 0.2
    
    classes = ['P','K','Mg','pH']
    class_dict= {0:'Phosphorous', 
                 1: 'Pottasium',
                 2: 'Magnesium',
                 3: 'PH'
                }

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# **Helper Function**

# %%
def load_npz_file(filepath,
                  masked = True,
                  pad_mask = True):
    '''load in numpy zipped files. Use masked =True to mask masked values (pad with 0's)'''
    with np.load(filepath) as npz:
        arr = np.ma.MaskedArray(**npz)
        
        
    if masked == True:
        if pad_mask : # pad masked pixels with 0's to preserve shape 
            mask = arr.mask 
            return np.where(mask==True,0,arr.data)
        
        return arr

    return arr.data

# %%
train_folder = '../input/ai4eo-predict-soil-components-concentrations/RawData/train_data'


# hyperspectral image tiles 
train_tiles_folder = '../input/ai4eo-predict-soil-components-concentrations/RawData/train_data/train_data/' 

test_tiles_folder = '../input/ai4eo-predict-soil-components-concentrations/RawData/test_data'

# %%
train_gt = pd.read_csv(train_folder + '/train_gt.csv')
wavelength = pd.read_csv(train_folder + '/wavelengths.csv')

train_gt.head()
# Out:
#    sample_index     P      K     Mg   pH
# 0             0  45.1  188.0  179.0  7.2
# 1             1  44.8  205.0  188.0  7.0
# 2             2  44.4  207.0  145.0  6.8
# 3             3  46.5  204.0  143.0  6.8
# 4             4  52.0  212.0  167.0  6.7

# %%
#adding paths to train_gt csv 
train_gt['paths'] = train_tiles_folder + train_gt['sample_index'].astype(str) + '.npz'

#check if all the paths exists 

all([os.path.exists(path) for path in train_gt['paths']])
# Out:
# True

# %% [markdown]
# **Making a test csv**

# %%
test_csv = pd.DataFrame({'paths':glob.glob(test_tiles_folder+'/*.npz')})

test_csv['sample_index'] = test_csv['paths'].apply(lambda x:x.split('/')[-1].split('.')[0])
test_csv['sample_index'] = test_csv['sample_index'].astype(int)

test_csv.sort_values(by ='sample_index', inplace=True )
test_csv.reset_index(inplace=True,drop=True)
test_csv.head()
# Out:
#                                                paths  sample_index
# 0  ../input/ai4eo-predict-soil-components-concent...             0
# 1  ../input/ai4eo-predict-soil-components-concent...             1
# 2  ../input/ai4eo-predict-soil-components-concent...             2
# 3  ../input/ai4eo-predict-soil-components-concent...             3
# 4  ../input/ai4eo-predict-soil-components-concent...             4

# %% [markdown]
# # Displaying some sample datapoints

# %%
# display a single band 

#choose a sample 
rand_sample_path = train_gt.sample(n=1)['paths'].values[0]


with np.load(rand_sample_path) as f :
    arr = np.ma.MaskedArray(**f)


color_print(f'Shape of the selected sample image {arr.shape} (channels, height,width)')




fig, axs = plt.subplots(1, 2, figsize=(10, 5))
band_id = 100
wavelen = wavelength.loc[band_id-1]


axs[0].imshow(arr[band_id,:,:].data)
plt.axis('off')
axs[0].set_title('Un masked array')

axs[1].imshow(arr[band_id,:,:])
plt.axis('off')
axs[1].set_title('masked array')




plt.suptitle(f'Representation of band {int(wavelen["band_no"])} ({wavelen["wavelength"]} nm)', fontsize=15)
plt.show()
# Out:
# Shape of the selected sample image (150, 11, 11) (channels, height,width)

# %%
# displaying spectral curve 

fig,ax = plt.subplots(figsize=(10, 5))

masked_scene_mean_spectral_reflectance = [arr[i,:,:].mean() for i in range(arr.shape[0])]
full_scene_mean_spectral_reflectance = [arr[i,:,:].data.mean() for i in range(arr.shape[0])]

plt.plot(wavelength['wavelength'], full_scene_mean_spectral_reflectance, label='Full image',color='g')
plt.plot(wavelength['wavelength'], masked_scene_mean_spectral_reflectance, label='Masked image',color='b')

plt.xlabel('[nm]')
plt.legend()
plt.title(f'Average reflectance for sample num {rand_sample_path}')
plt.show()

# %%
# display a single band 

#choose a sample 
rand_sample_path = train_gt.sample(n=1)['paths'].values[0]


with np.load(rand_sample_path) as f :
    arr = np.ma.MaskedArray(**f)

color_print(f'Shape of the selected sample image {arr.shape} (channels, height,width)')




fig, axs = plt.subplots(1, 2, figsize=(10, 5))
band_id = 1
wavelen = wavelength.loc[band_id-1]


axs[0].imshow(arr[band_id,:,:].data)
plt.axis('off')
axs[0].set_title('Un masked array')

axs[1].imshow(arr[band_id,:,:])
plt.axis('off')
axs[1].set_title('masked array')




plt.suptitle(f'Representation of band {int(wavelen["band_no"])} ({wavelen["wavelength"]} nm)', fontsize=15)
plt.show()
# Out:
# Shape of the selected sample image (150, 11, 11) (channels, height,width)

# %%
# displaying spectral curve 

fig,ax = plt.subplots(figsize=(10, 5))

masked_scene_mean_spectral_reflectance = [arr[i,:,:].mean() for i in range(arr.shape[0])]
full_scene_mean_spectral_reflectance = [arr[i,:,:].data.mean() for i in range(arr.shape[0])]

plt.plot(wavelength['wavelength'], full_scene_mean_spectral_reflectance, label='Full image',color='g')
plt.plot(wavelength['wavelength'], masked_scene_mean_spectral_reflectance, label='Masked image',color='b')

plt.xlabel('[nm]')
plt.legend()
plt.title(f'Average reflectance for sample num {rand_sample_path}')
plt.show()

# %%
# display a single band 

#choose a sample 
rand_sample_path = train_gt.sample(n=1)['paths'].values[0]


with np.load(rand_sample_path) as f :
    arr = np.ma.MaskedArray(**f)

color_print(f'Shape of the selected sample image {arr.shape} (channels, height,width)')




fig, axs = plt.subplots(1, 2, figsize=(10, 5))
band_id = 50
wavelen = wavelength.loc[band_id-1]


axs[0].imshow(arr[band_id,:,:].data)
plt.axis('off')
axs[0].set_title('Un masked array')

axs[1].imshow(arr[band_id,:,:])
plt.axis('off')
axs[1].set_title('masked array')




plt.suptitle(f'Representation of band {int(wavelen["band_no"])} ({wavelen["wavelength"]} nm)', fontsize=15)
plt.show()
# Out:
# Shape of the selected sample image (150, 130, 124) (channels, height,width)

# %%
# displaying spectral curve 

fig,ax = plt.subplots(figsize=(10, 5))

masked_scene_mean_spectral_reflectance = [arr[i,:,:].mean() for i in range(arr.shape[0])]
full_scene_mean_spectral_reflectance = [arr[i,:,:].data.mean() for i in range(arr.shape[0])]

plt.plot(wavelength['wavelength'], full_scene_mean_spectral_reflectance, label='Full image',color='g')
plt.plot(wavelength['wavelength'], masked_scene_mean_spectral_reflectance, label='Masked image',color='b')

plt.xlabel('[nm]')
plt.legend()
plt.title(f'Average reflectance for sample num {rand_sample_path}')
plt.show()

# %% [markdown]
# **Checking range of data values(for scaling Images)**

# %%
band_vals = []
heights = []
widths = []

for rast in train_gt.paths:
    arr = load_npz_file(rast,masked=True,pad_mask=False)
    
    # take max value 
    max_vals = arr.max(axis=(1,2))
    band_vals.append(max_vals)
    
    # get image heights and widths 
    unmasked = arr.data 
    
    c,h,w = unmasked.shape
    
    heights.append(h)
    widths.append(w)
    
    
    
band_vals= np.array(band_vals)
    
mean_band_vals = band_vals.mean(axis=0)

plt.imshow(mean_band_vals.reshape((10,15)))

# %% [markdown]
# **Distribution of Image Height and widths**
#
#     Images have different heights and widths, so lets take a look at that distribution

# %%
plt.figure(figsize=(20,10))
plt.yticks(fontsize=16)

sns.distplot(a = heights,color = 'b',label = 'height',hist=False)
sns.distplot(a = widths,color = 'g',label = 'widh',hist=False)

plt.title("Distribution of Image shapes",
          font="Serif", 
          size=20,
          color='k')
plt.xlim((0,150))

plt.legend()

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Building Train and test datasets

# %%
def load_and_reshape(filepath):
    '''load and reshape array'''
    
    filepath = filepath.numpy().decode('utf-8')
    
    #load array
    arr = load_npz_file(filepath,
                        masked=True,
                        pad_mask=True)
    
    depth,height,width = arr.shape
    
    # reshape to depth last format 
    arr = arr.reshape((height,width,depth))
    
#     scale values 
    arr = arr / mean_band_vals
    
#     resize 
    arr = cv2.resize(arr,CFG.img_size)
    
    return arr


def process_image(filename):
    '''function for preprocessing in tensorflow data'''
    
    return tf.py_function(load_and_reshape, 
                          [filename], 
                          tf.float32)

# %% [markdown]
# # Data Pipelines

# %%
train_ds,val_ds = train_test_split(train_gt,
                                  test_size = CFG.validation_size,
                                  random_state = CFG.seed)



train_ds.shape,val_ds.shape
# Out:
# ((1385, 6), (347, 6))

# %%
def augment_image(image):
    '''perform simple image augmentations'''
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_crop(image, size=(*CFG.img_size,150))
    
    rot = tf.random.normal((1,),mean = 0.35, stddev=0.15)
    
    if rot > 0.5:
        image = tf.image.rot90(image)

    return image

# %%
def get_tf_dataset(image_paths,
                   labels=None, # put none for test data set
                   image_processing_fn=process_image,
                   augment_fn = None
                  ):
    
    '''returns a tf dataset object'''
    
    #seperate datasets
    if labels is not None:
        labels_dataset = tf.data.Dataset.from_tensor_slices(labels)
    
    
    
    image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
    #load images 
    image_dataset = image_dataset.map(image_processing_fn,
                                      num_parallel_calls=tf.data.AUTOTUNE)
     
    if augment_fn is not None:
        
        image_dataset = image_dataset.map(augment_fn,
                                          num_parallel_calls=tf.data.AUTOTUNE)
     
    
    if labels is not None:
        return tf.data.Dataset.zip((image_dataset,labels_dataset))
    
    
    return image_dataset


def optimize_pipeline(tf_dataset,
                      batch_size = CFG.BATCH_SIZE,
                      Autotune_fn = CFG.Autotune,
                      cache= False,
                      batch = True):
    
    
    
    # prefetch(load the data with cpu,while gpu is training) the data in memory 
    tf_dataset = tf_dataset.prefetch(buffer_size=Autotune_fn)  
    if cache:
        tf_dataset = tf_dataset.cache()                        # store data in RAM  
        
    tf_dataset =  tf_dataset.shuffle(buffer_size=50)         # shuffle 
    
    if batch:
        tf_dataset = tf_dataset.batch(batch_size)              #split the data in batches  
    
    return tf_dataset





Training_Dataset = optimize_pipeline(get_tf_dataset(image_paths = train_ds.paths.values,
                                               labels = train_ds[CFG.classes].values,
                                               image_processing_fn = process_image,
                                              augment_fn=augment_image)
                              )


Val_Dataset = optimize_pipeline(get_tf_dataset(image_paths = val_ds.paths.values,
                                               labels = val_ds[CFG.classes].values,
                                               image_processing_fn = process_image,
                                               augment_fn=augment_image)
                              )



Test_Dataset = optimize_pipeline(get_tf_dataset(image_paths = test_csv.paths.values,
                                               labels = None,
                                               image_processing_fn = process_image,
                                               augment_fn=augment_image)
                              )

# %% [markdown]
# **CHeck the dataset**

# %%
for x,y in Training_Dataset.take(1): # take one batch for checking 
    print(f'Training data batch : {x.shape}')
    
    plt.imshow(x[0,:,:,100],cmap='gray')
    plt.title('sample image')
# Out:
# Training data batch : (32, 60, 60, 150)

# %% [markdown]
# # Building a cnn

# %%
#hidden units in each branch 
n_hidden = [32,32,32,32]



# input layer
inp =tf.keras.layers.Input(shape = (*CFG.img_size,150))




# L1

x0 = tf.keras.layers.Conv2D(32,
           activation='relu',
           kernel_size=7,
           strides =2
          )(inp)

x0 = tf.keras.layers.BatchNormalization()(x0)



# seperate branches for each output 


# phosphorous branch 

x1 = tf.keras.layers.Conv2D(64,
           activation='relu',
           kernel_size=3,
           strides =2
          )(x0)
x1 = tf.keras.layers.BatchNormalization()(x1)


# x1 = tf.keras.layers.Conv2D(128,
#            activation='relu',
#            kernel_size=3,
#            strides =2
#           )(x1)
# x1 = tf.keras.layers.BatchNormalization()(x1)


x1 = tf.keras.layers.Flatten()(x1)
# x1 = tf.keras.layers.Dropout(0.15)(x1)


x1 = tf.keras.layers.Dense(n_hidden[0])(x1)
x1 = tf.keras.layers.Dropout(0.15)(x1)
x1 = tf.keras.layers.BatchNormalization()(x1)

out1 = tf.keras.layers.Dense(1,
                            activation='linear',name = 'Phos')(x1)


# K branch 

x2 = tf.keras.layers.Conv2D(64,
           activation='relu',
           kernel_size=3,
           strides =2
          )(x0)
x2 = tf.keras.layers.BatchNormalization()(x2)


x2 = tf.keras.layers.Flatten()(x2)
# x2 = tf.keras.layers.Dropout(0.15)(x2)



x2 = tf.keras.layers.Dense(n_hidden[1])(x2)
x2 = tf.keras.layers.Dropout(0.15)(x2)
x2 = tf.keras.layers.BatchNormalization()(x2)



out2 = tf.keras.layers.Dense(1,
                            activation='linear',name = 'K')(x2)

# mg branch 

x3 = tf.keras.layers.Conv2D(64,
           activation='relu',
           kernel_size=3,
           strides =2
          )(x0)
x3 = tf.keras.layers.BatchNormalization()(x3)


x3 = tf.keras.layers.Conv2D(128,
           activation='relu',
           kernel_size=3,
           strides =2
          )(x3)
x3 = tf.keras.layers.BatchNormalization()(x3)


x3 = tf.keras.layers.Flatten()(x3)
# x3 = tf.keras.layers.Dropout(0.15)(x3)
x3 = tf.keras.layers.Dense(n_hidden[2])(x3)
x3 = tf.keras.layers.Dropout(0.15)(x3)
x3 = tf.keras.layers.BatchNormalization()(x3)

out3 = tf.keras.layers.Dense(1,
                            activation='linear',name = 'Mg')(x3)


# ph branch 

x4 = tf.keras.layers.Conv2D(64,
           activation='relu',
           kernel_size=3,
           strides =2
          )(x0)
x4 = tf.keras.layers.BatchNormalization()(x4)

x4 = tf.keras.layers.Flatten()(x4)
# x4 = tf.keras.layers.Dropout(0.25)(x4)



x4 = tf.keras.layers.Dense(n_hidden[3])(x4)
x4 = tf.keras.layers.Dropout(0.15)(x4)
x4 = tf.keras.layers.BatchNormalization()(x4)


out4 = tf.keras.layers.Dense(1,
                            activation='linear',name = 'PH')(x4)


model = tf.keras.Model(inputs=[inp],outputs = [out1,out2,out3,out4])




print('Model Architecture')

tf.keras.utils.plot_model(model)
# Out:
# Model Architecture

# %% [markdown]
# # Training

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.05),
              loss = 'mean_squared_error',
              metrics = tf.keras.metrics.MAE)


# to save model 
# !mkdir CNN_models

# %%
EPOCHS = 30
# callbacks 
#reduce_learning rate
reduce_lr=tf.keras.callbacks.ReduceLROnPlateau(patience=2,
                                                factor=0.75,
                                                min_delta=1e-2,
                                                monitor='val_loss',
                                                verbose=1,
                                                mode='min')

#early stopping 
early_stopping=tf.keras.callbacks.EarlyStopping(patience=10,
                                             min_delta=1e-2,
                                              monitor='val_loss',
                                              restore_best_weights=True,
                                              mode='min')


# exponential decay 

def lr_scheduler(epoch, lr):

    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.02)
    

    
learning_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)



callbacks_1= [reduce_lr,early_stopping,learning_scheduler]



hist1 = model.fit(Training_Dataset,
                    validation_data = Val_Dataset,
                    epochs = EPOCHS,
                    callbacks = callbacks_1
                   )


model.save(filepath = '/kaggle/working/CNN_models/CNN_model.h5')
# Out:
# Epoch 1/30
# 44/44 [==============================] - 24s 537ms/step - loss: 34985.3594 - Phos_loss: 8746.0654 - K_loss: 8744.3145 - Mg_loss: 8747.2979 - PH_loss: 8747.6875 - Phos_mean_absolute_error: 79.8803 - K_mean_absolute_error: 79.8797 - Mg_mean_absolute_error: 79.8807 - PH_mean_absolute_error: 79.8820 - val_loss: 33689.0703 - val_Phos_loss: 8422.1543 - val_K_loss: 8415.3623 - val_Mg_loss: 8424.9141 - val_PH_loss: 8426.6387 - val_Phos_mean_absolute_error: 78.3342 - val_K_mean_absolute_error: 78.3177 - val_Mg_mean_absolute_error: 78.3715 - val_PH_mean_absolute_error: 78.3768
# Epoch 2/30
# 44/44 [==============================] - 24s 541ms/step - loss: 35012.3789 - Phos_loss: 8751.5957 - K_loss: 8755.8213 - Mg_loss: 8751.0430 - PH_loss: 8753.9189 - Phos_mean_absolute_error: 79.9079 - K_mean_absolute_error: 79.8970 - Mg_mean_absolute_error: 79.8877 - PH_mean_absolute_error: 79.9078 - val_loss: 33692.3789 - val_Phos_loss: 8424.9795 - val_K_loss: 8424.6875 - val_Mg_loss: 8424.7324 - val_PH_loss: 8417.9766 - val_Phos_mean_absolute_error: 78.2834 - val_K_mean_absolute_error: 78.3413 - val_Mg_mean_absolute_error: 78.3345 - val_PH_mean_absolute_error: 78.3139
# Epoch 3/30
# 44/44 [==============================] - 24s 540ms/step - loss: 35021.3125 - Phos_loss: 8755.1084 - K_loss: 8757.0459 - Mg_loss: 8755.3418 - PH_loss: 8753.8154 - Phos_mean_absolute_error: 79.9019 - K_mean_absolute_error: 79.9064 - Mg_mean_absolute_error: 79.9031 - PH_mean_absolute_error: 79.9046 - val_loss: 33687.9883 - val_Phos_loss: 8418.7969 - val_K_loss: 8428.5684 - val_Mg_loss: 8422.3281 - val_PH_loss: 8418.2939 - val_Phos_mean_absolute_error: 78.3329 - val_K_mean_absolute_error: 78.3704 - val_Mg_mean_absolute_error: 78.3623 - val_PH_mean_absolute_error: 78.3484
# Epoch 4/30
# 44/44 [==============================] - 24s 534ms/step - loss: 35026.2070 - Phos_loss: 8755.2852 - K_loss: 8756.4385 - Mg_loss: 8756.7910 - PH_loss: 8757.6953 - Phos_mean_absolute_error: 79.9086 - K_mean_absolute_error: 79.9068 - Mg_mean_absolute_error: 79.9050 - PH_mean_absolute_error: 79.9265 - val_loss: 33718.4531 - val_Phos_loss: 8442.7549 - val_K_loss: 8424.0723 - val_Mg_loss: 8429.5732 - val_PH_loss: 8422.0479 - val_Phos_mean_absolute_error: 78.2446 - val_K_mean_absolute_error: 78.2976 - val_Mg_mean_absolute_error: 78.2665 - val_PH_mean_absolute_error: 78.2847
# Epoch 5/30
# 44/44 [==============================] - 24s 533ms/step - loss: 35022.9883 - Phos_loss: 8754.6885 - K_loss: 8753.3447 - Mg_loss: 8757.2041 - PH_loss: 8757.7480 - Phos_mean_absolute_error: 79.9213 - K_mean_absolute_error: 79.9057 - Mg_mean_absolute_error: 79.9032 - PH_mean_absolute_error: 79.9287 - val_loss: 33693.1172 - val_Phos_loss: 8421.1191 - val_K_loss: 8426.4365 - val_Mg_loss: 8428.1855 - val_PH_loss: 8417.3779 - val_Phos_mean_absolute_error: 78.3416 - val_K_mean_absolute_error: 78.3662 - val_Mg_mean_absolute_error: 78.3800 - val_PH_mean_absolute_error: 78.3398
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.037500000558793545.
# Epoch 6/30
# 44/44 [==============================] - 24s 535ms/step - loss: 35022.1250 - Phos_loss: 8755.3184 - K_loss: 8753.5996 - Mg_loss: 8757.5146 - PH_loss: 8755.6914 - Phos_mean_absolute_error: 79.9005 - K_mean_absolute_error: 79.8847 - Mg_mean_absolute_error: 79.8928 - PH_mean_absolute_error: 79.8930 - val_loss: 33681.9648 - val_Phos_loss: 8422.2471 - val_K_loss: 8417.8359 - val_Mg_loss: 8420.0010 - val_PH_loss: 8421.8818 - val_Phos_mean_absolute_error: 78.3589 - val_K_mean_absolute_error: 78.3353 - val_Mg_mean_absolute_error: 78.3467 - val_PH_mean_absolute_error: 78.3498
# Epoch 7/30
# 44/44 [==============================] - 24s 541ms/step - loss: 35011.3828 - Phos_loss: 8753.2227 - K_loss: 8752.0566 - Mg_loss: 8753.5195 - PH_loss: 8752.5859 - Phos_mean_absolute_error: 79.9066 - K_mean_absolute_error: 79.9219 - Mg_mean_absolute_error: 79.9214 - PH_mean_absolute_error: 79.9166 - val_loss: 33666.3203 - val_Phos_loss: 8416.6943 - val_K_loss: 8417.4521 - val_Mg_loss: 8416.0566 - val_PH_loss: 8416.1143 - val_Phos_mean_absolute_error: 78.3412 - val_K_mean_absolute_error: 78.3149 - val_Mg_mean_absolute_error: 78.3264 - val_PH_mean_absolute_error: 78.3302
# Epoch 8/30
# 44/44 [==============================] - 24s 539ms/step - loss: 35003.6953 - Phos_loss: 8748.8574 - K_loss: 8753.4834 - Mg_loss: 8750.4785 - PH_loss: 8750.8770 - Phos_mean_absolute_error: 79.8754 - K_mean_absolute_error: 79.8815 - Mg_mean_absolute_error: 79.8824 - PH_mean_absolute_error: 79.8867 - val_loss: 33681.9297 - val_Phos_loss: 8417.9248 - val_K_loss: 8419.2812 - val_Mg_loss: 8422.0830 - val_PH_loss: 8422.6387 - val_Phos_mean_absolute_error: 78.3495 - val_K_mean_absolute_error: 78.3328 - val_Mg_mean_absolute_error: 78.3669 - val_PH_mean_absolute_error: 78.3726
# Epoch 9/30
# 44/44 [==============================] - 24s 537ms/step - loss: 34997.6445 - Phos_loss: 8750.7842 - K_loss: 8749.2324 - Mg_loss: 8748.3643 - PH_loss: 8749.2568 - Phos_mean_absolute_error: 79.8924 - K_mean_absolute_error: 79.8758 - Mg_mean_absolute_error: 79.8906 - PH_mean_absolute_error: 79.8773 - val_loss: 33679.3594 - val_Phos_loss: 8421.4248 - val_K_loss: 8418.6719 - val_Mg_loss: 8423.5977 - val_PH_loss: 8415.6670 - val_Phos_mean_absolute_error: 78.3488 - val_K_mean_absolute_error: 78.3429 - val_Mg_mean_absolute_error: 78.3646 - val_PH_mean_absolute_error: 78.3256
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.02812500111758709.
# Epoch 10/30
# 44/44 [==============================] - 24s 534ms/step - loss: 34999.8359 - Phos_loss: 8749.5977 - K_loss: 8753.1885 - Mg_loss: 8748.7754 - PH_loss: 8748.2764 - Phos_mean_absolute_error: 79.8807 - K_mean_absolute_error: 79.8725 - Mg_mean_absolute_error: 79.8729 - PH_mean_absolute_error: 79.8723 - val_loss: 33683.2305 - val_Phos_loss: 8421.2637 - val_K_loss: 8420.9268 - val_Mg_loss: 8420.4980 - val_PH_loss: 8420.5410 - val_Phos_mean_absolute_error: 78.3616 - val_K_mean_absolute_error: 78.3649 - val_Mg_mean_absolute_error: 78.3582 - val_PH_mean_absolute_error: 78.3550
# Epoch 11/30
# 44/44 [==============================] - 24s 534ms/step - loss: 35004.9453 - Phos_loss: 8750.8545 - K_loss: 8752.3555 - Mg_loss: 8749.4170 - PH_loss: 8752.3213 - Phos_mean_absolute_error: 79.8990 - K_mean_absolute_error: 79.9152 - Mg_mean_absolute_error: 79.9089 - PH_mean_absolute_error: 79.9047 - val_loss: 33686.9336 - val_Phos_loss: 8418.0068 - val_K_loss: 8419.4766 - val_Mg_loss: 8433.7217 - val_PH_loss: 8415.7285 - val_Phos_mean_absolute_error: 78.3539 - val_K_mean_absolute_error: 78.3491 - val_Mg_mean_absolute_error: 78.3470 - val_PH_mean_absolute_error: 78.3265
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.020676066633313894.
# Epoch 12/30
# 44/44 [==============================] - 24s 541ms/step - loss: 34980.1172 - Phos_loss: 8745.5449 - K_loss: 8746.9609 - Mg_loss: 8746.9512 - PH_loss: 8740.6572 - Phos_mean_absolute_error: 79.8887 - K_mean_absolute_error: 79.8817 - Mg_mean_absolute_error: 79.8838 - PH_mean_absolute_error: 79.8756 - val_loss: 33710.9961 - val_Phos_loss: 8425.0508 - val_K_loss: 8426.9736 - val_Mg_loss: 8439.9268 - val_PH_loss: 8419.0449 - val_Phos_mean_absolute_error: 78.3663 - val_K_mean_absolute_error: 78.3688 - val_Mg_mean_absolute_error: 78.4062 - val_PH_mean_absolute_error: 78.3067
# Epoch 13/30
# 44/44 [==============================] - 24s 534ms/step - loss: 34993.0508 - Phos_loss: 8747.7607 - K_loss: 8749.3184 - Mg_loss: 8746.7295 - PH_loss: 8749.2461 - Phos_mean_absolute_error: 79.8904 - K_mean_absolute_error: 79.8868 - Mg_mean_absolute_error: 79.8833 - PH_mean_absolute_error: 79.8891 - val_loss: 34690.8945 - val_Phos_loss: 8482.6455 - val_K_loss: 8443.2842 - val_Mg_loss: 9338.4688 - val_PH_loss: 8426.4941 - val_Phos_mean_absolute_error: 78.6143 - val_K_mean_absolute_error: 78.4265 - val_Mg_mean_absolute_error: 79.8783 - val_PH_mean_absolute_error: 78.3942
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.014899010304361582.
# Epoch 14/30
# 44/44 [==============================] - 24s 535ms/step - loss: 34986.6328 - Phos_loss: 8747.2705 - K_loss: 8745.9971 - Mg_loss: 8745.2012 - PH_loss: 8748.1494 - Phos_mean_absolute_error: 79.8733 - K_mean_absolute_error: 79.8831 - Mg_mean_absolute_error: 79.8751 - PH_mean_absolute_error: 79.8891 - val_loss: 34103.4531 - val_Phos_loss: 8426.0732 - val_K_loss: 8517.6680 - val_Mg_loss: 8728.4375 - val_PH_loss: 8431.2705 - val_Phos_mean_absolute_error: 78.3251 - val_K_mean_absolute_error: 78.6382 - val_Mg_mean_absolute_error: 79.0415 - val_PH_mean_absolute_error: 78.3297
# Epoch 15/30
# 44/44 [==============================] - 24s 541ms/step - loss: 34973.8203 - Phos_loss: 8740.2549 - K_loss: 8745.0508 - Mg_loss: 8744.3115 - PH_loss: 8744.2021 - Phos_mean_absolute_error: 79.8679 - K_mean_absolute_error: 79.8780 - Mg_mean_absolute_error: 79.8751 - PH_mean_absolute_error: 79.8836 - val_loss: 33657.8281 - val_Phos_loss: 8409.7344 - val_K_loss: 8417.4219 - val_Mg_loss: 8413.5244 - val_PH_loss: 8417.1543 - val_Phos_mean_absolute_error: 78.3135 - val_K_mean_absolute_error: 78.2974 - val_Mg_mean_absolute_error: 78.3210 - val_PH_mean_absolute_error: 78.2871
# Epoch 16/30
# 44/44 [==============================] - 24s 540ms/step - loss: 34965.1992 - Phos_loss: 8740.8428 - K_loss: 8744.5840 - Mg_loss: 8740.8037 - PH_loss: 8738.9678 - Phos_mean_absolute_error: 79.8779 - K_mean_absolute_error: 79.8844 - Mg_mean_absolute_error: 79.8827 - PH_mean_absolute_error: 79.8658 - val_loss: 33729.7734 - val_Phos_loss: 8433.8242 - val_K_loss: 8418.9160 - val_Mg_loss: 8434.8730 - val_PH_loss: 8442.1582 - val_Phos_mean_absolute_error: 78.4053 - val_K_mean_absolute_error: 78.3622 - val_Mg_mean_absolute_error: 78.4029 - val_PH_mean_absolute_error: 78.4269
# Epoch 17/30
# 44/44 [==============================] - 24s 538ms/step - loss: 34973.0234 - Phos_loss: 8743.7441 - K_loss: 8745.7617 - Mg_loss: 8745.2998 - PH_loss: 8738.2207 - Phos_mean_absolute_error: 79.8531 - K_mean_absolute_error: 79.8771 - Mg_mean_absolute_error: 79.8484 - PH_mean_absolute_error: 79.8450 - val_loss: 33632.8828 - val_Phos_loss: 8410.1416 - val_K_loss: 8412.3955 - val_Mg_loss: 8404.6289 - val_PH_loss: 8405.7178 - val_Phos_mean_absolute_error: 78.3135 - val_K_mean_absolute_error: 78.3160 - val_Mg_mean_absolute_error: 78.2772 - val_PH_mean_absolute_error: 78.2936
# Epoch 18/30
# 44/44 [==============================] - 24s 539ms/step - loss: 34946.3516 - Phos_loss: 8735.2461 - K_loss: 8739.2012 - Mg_loss: 8735.3340 - PH_loss: 8736.5703 - Phos_mean_absolute_error: 79.8597 - K_mean_absolute_error: 79.8639 - Mg_mean_absolute_error: 79.8522 - PH_mean_absolute_error: 79.8521 - val_loss: 33647.2773 - val_Phos_loss: 8423.9932 - val_K_loss: 8413.3887 - val_Mg_loss: 8406.9834 - val_PH_loss: 8402.9141 - val_Phos_mean_absolute_error: 78.4019 - val_K_mean_absolute_error: 78.3476 - val_Mg_mean_absolute_error: 78.3507 - val_PH_mean_absolute_error: 78.3347
# Epoch 19/30
# 44/44 [==============================] - 24s 535ms/step - loss: 34937.2305 - Phos_loss: 8731.5996 - K_loss: 8737.3896 - Mg_loss: 8732.8086 - PH_loss: 8735.4336 - Phos_mean_absolute_error: 79.8378 - K_mean_absolute_error: 79.8577 - Mg_mean_absolute_error: 79.8504 - PH_mean_absolute_error: 79.8248 - val_loss: 38050.5781 - val_Phos_loss: 8829.9033 - val_K_loss: 8729.1328 - val_Mg_loss: 11881.0771 - val_PH_loss: 8610.4600 - val_Phos_mean_absolute_error: 79.1208 - val_K_mean_absolute_error: 79.0049 - val_Mg_mean_absolute_error: 81.2428 - val_PH_mean_absolute_error: 78.3960
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00991067779250443.
# Epoch 20/30
# 44/44 [==============================] - 24s 538ms/step - loss: 34918.7109 - Phos_loss: 8731.3389 - K_loss: 8731.1670 - Mg_loss: 8728.4229 - PH_loss: 8727.7822 - Phos_mean_absolute_error: 79.8315 - K_mean_absolute_error: 79.8308 - Mg_mean_absolute_error: 79.8193 - PH_mean_absolute_error: 79.8197 - val_loss: 40509.8164 - val_Phos_loss: 8915.3730 - val_K_loss: 8800.6025 - val_Mg_loss: 14220.9971 - val_PH_loss: 8572.8408 - val_Phos_mean_absolute_error: 79.2169 - val_K_mean_absolute_error: 79.1218 - val_Mg_mean_absolute_error: 82.1928 - val_PH_mean_absolute_error: 78.3875
# Epoch 21/30
# 44/44 [==============================] - 24s 534ms/step - loss: 34944.4609 - Phos_loss: 8732.8955 - K_loss: 8739.3037 - Mg_loss: 8734.5107 - PH_loss: 8737.7500 - Phos_mean_absolute_error: 79.8507 - K_mean_absolute_error: 79.8672 - Mg_mean_absolute_error: 79.8572 - PH_mean_absolute_error: 79.8551 - val_loss: 33744.8516 - val_Phos_loss: 8424.6250 - val_K_loss: 8433.4082 - val_Mg_loss: 8426.7676 - val_PH_loss: 8460.0479 - val_Phos_mean_absolute_error: 78.3956 - val_K_mean_absolute_error: 78.4138 - val_Mg_mean_absolute_error: 78.4247 - val_PH_mean_absolute_error: 78.5031
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00714155612513423.
# Epoch 22/30
# 44/44 [==============================] - 24s 532ms/step - loss: 34919.6055 - Phos_loss: 8731.5918 - K_loss: 8730.6816 - Mg_loss: 8728.6055 - PH_loss: 8728.7178 - Phos_mean_absolute_error: 79.8241 - K_mean_absolute_error: 79.8335 - Mg_mean_absolute_error: 79.8212 - PH_mean_absolute_error: 79.8188 - val_loss: 33626.1367 - val_Phos_loss: 8419.0127 - val_K_loss: 8400.4717 - val_Mg_loss: 8406.5752 - val_PH_loss: 8400.0781 - val_Phos_mean_absolute_error: 78.2991 - val_K_mean_absolute_error: 78.3177 - val_Mg_mean_absolute_error: 78.3005 - val_PH_mean_absolute_error: 78.3290
# Epoch 23/30
# 44/44 [==============================] - 25s 546ms/step - loss: 34917.9219 - Phos_loss: 8726.2734 - K_loss: 8733.0723 - Mg_loss: 8730.2490 - PH_loss: 8728.3311 - Phos_mean_absolute_error: 79.8081 - K_mean_absolute_error: 79.8338 - Mg_mean_absolute_error: 79.8129 - PH_mean_absolute_error: 79.8103 - val_loss: 34008.0195 - val_Phos_loss: 8519.3662 - val_K_loss: 8429.2051 - val_Mg_loss: 8567.3506 - val_PH_loss: 8492.0957 - val_Phos_mean_absolute_error: 78.3278 - val_K_mean_absolute_error: 78.2688 - val_Mg_mean_absolute_error: 78.3696 - val_PH_mean_absolute_error: 78.2885
# Epoch 24/30
# 44/44 [==============================] - 24s 537ms/step - loss: 34919.4375 - Phos_loss: 8729.9863 - K_loss: 8731.6309 - Mg_loss: 8728.8916 - PH_loss: 8728.9238 - Phos_mean_absolute_error: 79.8308 - K_mean_absolute_error: 79.8388 - Mg_mean_absolute_error: 79.8352 - PH_mean_absolute_error: 79.8301 - val_loss: 69685.2188 - val_Phos_loss: 9285.5654 - val_K_loss: 9350.7070 - val_Mg_loss: 42240.1289 - val_PH_loss: 8808.8086 - val_Phos_mean_absolute_error: 79.5663 - val_K_mean_absolute_error: 79.6513 - val_Mg_mean_absolute_error: 87.9423 - val_PH_mean_absolute_error: 78.9687
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.005044248537160456.
# Epoch 25/30
# 44/44 [==============================] - 25s 545ms/step - loss: 34905.6680 - Phos_loss: 8722.9590 - K_loss: 8728.1094 - Mg_loss: 8726.9307 - PH_loss: 8727.6631 - Phos_mean_absolute_error: 79.7889 - K_mean_absolute_error: 79.8041 - Mg_mean_absolute_error: 79.8059 - PH_mean_absolute_error: 79.8006 - val_loss: 96911.5703 - val_Phos_loss: 10233.2471 - val_K_loss: 10067.6738 - val_Mg_loss: 67653.2812 - val_PH_loss: 8957.3564 - val_Phos_mean_absolute_error: 80.3682 - val_K_mean_absolute_error: 80.2694 - val_Mg_mean_absolute_error: 91.1984 - val_PH_mean_absolute_error: 79.3081
# Epoch 26/30
# 44/44 [==============================] - 24s 534ms/step - loss: 34906.1055 - Phos_loss: 8726.5703 - K_loss: 8728.9121 - Mg_loss: 8725.0732 - PH_loss: 8725.5479 - Phos_mean_absolute_error: 79.8097 - K_mean_absolute_error: 79.8257 - Mg_mean_absolute_error: 79.8044 - PH_mean_absolute_error: 79.8162 - val_loss: 71236.6875 - val_Phos_loss: 9423.9365 - val_K_loss: 9336.9434 - val_Mg_loss: 43776.5898 - val_PH_loss: 8699.2070 - val_Phos_mean_absolute_error: 79.7667 - val_K_mean_absolute_error: 79.6935 - val_Mg_mean_absolute_error: 88.2003 - val_PH_mean_absolute_error: 78.9230
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.003634845488704741.
# Epoch 27/30
# 44/44 [==============================] - 24s 537ms/step - loss: 34900.8633 - Phos_loss: 8725.1260 - K_loss: 8724.9043 - Mg_loss: 8724.6963 - PH_loss: 8726.1396 - Phos_mean_absolute_error: 79.8043 - K_mean_absolute_error: 79.8077 - Mg_mean_absolute_error: 79.8026 - PH_mean_absolute_error: 79.8038 - val_loss: 34796.4023 - val_Phos_loss: 8453.4473 - val_K_loss: 8429.4922 - val_Mg_loss: 9465.2217 - val_PH_loss: 8448.2422 - val_Phos_mean_absolute_error: 78.4404 - val_K_mean_absolute_error: 78.3645 - val_Mg_mean_absolute_error: 79.8205 - val_PH_mean_absolute_error: 78.4186
# Epoch 28/30
# 44/44 [==============================] - 24s 537ms/step - loss: 34890.2891 - Phos_loss: 8722.2949 - K_loss: 8722.1582 - Mg_loss: 8721.9033 - PH_loss: 8723.9316 - Phos_mean_absolute_error: 79.7990 - K_mean_absolute_error: 79.7959 - Mg_mean_absolute_error: 79.8049 - PH_mean_absolute_error: 79.8022 - val_loss: 33603.7383 - val_Phos_loss: 8397.8379 - val_K_loss: 8396.8721 - val_Mg_loss: 8411.7090 - val_PH_loss: 8397.3174 - val_Phos_mean_absolute_error: 78.2855 - val_K_mean_absolute_error: 78.2992 - val_Mg_mean_absolute_error: 78.2951 - val_PH_mean_absolute_error: 78.2947
# Epoch 29/30
# 44/44 [==============================] - 24s 539ms/step - loss: 34899.5273 - Phos_loss: 8725.5732 - K_loss: 8724.9922 - Mg_loss: 8724.2861 - PH_loss: 8724.6748 - Phos_mean_absolute_error: 79.8306 - K_mean_absolute_error: 79.8250 - Mg_mean_absolute_error: 79.8274 - PH_mean_absolute_error: 79.8200 - val_loss: 33618.6016 - val_Phos_loss: 8403.2676 - val_K_loss: 8397.6816 - val_Mg_loss: 8417.1680 - val_PH_loss: 8400.4883 - val_Phos_mean_absolute_error: 78.3079 - val_K_mean_absolute_error: 78.3220 - val_Mg_mean_absolute_error: 78.3346 - val_PH_mean_absolute_error: 78.3142
# Epoch 30/30
# 44/44 [==============================] - 24s 531ms/step - loss: 34895.8086 - Phos_loss: 8723.2324 - K_loss: 8723.6807 - Mg_loss: 8724.6904 - PH_loss: 8724.2031 - Phos_mean_absolute_error: 79.8139 - K_mean_absolute_error: 79.8212 - Mg_mean_absolute_error: 79.8282 - PH_mean_absolute_error: 79.8193 - val_loss: 33636.7852 - val_Phos_loss: 8411.1104 - val_K_loss: 8402.7285 - val_Mg_loss: 8417.1143 - val_PH_loss: 8405.8330 - val_Phos_mean_absolute_error: 78.3070 - val_K_mean_absolute_error: 78.3193 - val_Mg_mean_absolute_error: 78.3028 - val_PH_mean_absolute_error: 78.3020
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0025165389524772763.

# %%
def TTA_prediction_individual(model, test_dataset, num_repeats):
    preds = []

    for _ in tqdm(range(num_repeats), desc='Prediction Number'):
        pred = model.predict(test_dataset)
        preds.append(pred)

    preds = np.array(preds)
    return preds

# %%
# With this line
preds_individual = TTA_prediction_individual(model=model, test_dataset=Test_Dataset, num_repeats=10)
# Out:
# Prediction Number: 100%|██████████| 10/10 [02:18<00:00, 13.85s/it]

# %%
# Access predictions for the first sample
first_sample_preds = preds_individual[0]
print(first_sample_preds)
# Out:
# [[[113.72617 ]
#   [110.21464 ]
#   [112.76403 ]
#   ...
#   [110.43808 ]
#   [108.50362 ]
#   [109.80144 ]]
#
#  [[114.20736 ]
#   [112.05476 ]
#   [114.83088 ]
#   ...
#   [112.60211 ]
#   [110.67489 ]
#   [112.09793 ]]
#
#  [[111.1972  ]
#   [112.03216 ]
#   [111.33718 ]
#   ...
#   [110.66922 ]
#   [109.206   ]
#   [109.125404]]
#
#  [[111.330986]
#   [111.83051 ]
#   [113.43664 ]
#   ...
#   [111.64899 ]
#   [110.078445]
#   [111.52695 ]]]

# %%
# Assuming preds_individual is a list of individual predictions
for i, component in enumerate(CFG.classes):
    component_preds = preds_individual[:, :, i].squeeze(axis=-1)
    component_df = pd.DataFrame(component_preds, columns=[f'{component}_{j}' for j in range(preds_individual.shape[1])])
    component_df.to_csv(f'{component}_individual_preds.csv', index_label='sample_index')

# %%
print(preds_individual )
# Out:
# [[[[113.72617 ]
#    [110.21464 ]
#    [112.76403 ]
#    ...
#    [110.43808 ]
#    [108.50362 ]
#    [109.80144 ]]
#
#   [[114.20736 ]
#    [112.05476 ]
#    [114.83088 ]
#    ...
#    [112.60211 ]
#    [110.67489 ]
#    [112.09793 ]]
#
#   [[111.1972  ]
#    [112.03216 ]
#    [111.33718 ]
#    ...
#    [110.66922 ]
#    [109.206   ]
#    [109.125404]]
#
#   [[111.330986]
#    [111.83051 ]
#    [113.43664 ]
#    ...
#    [111.64899 ]
#    [110.078445]
#    [111.52695 ]]]
#
#
#  [[[110.43457 ]
#    [110.328545]
#    [110.143394]
#    ...
#    [112.56198 ]
#    [111.36012 ]
#    [112.080414]]
#
#   [[112.49111 ]
#    [111.63496 ]
#    [111.875084]
#    ...
#    [113.29644 ]
#    [113.35562 ]
#    [113.64603 ]]
#
#   [[109.67281 ]
#    [110.44758 ]
#    [110.16807 ]
#    ...
#    [112.06383 ]
#    [111.30571 ]
#    [112.630684]]
#
#   [[111.620056]
#    [111.66516 ]
#    [111.72177 ]
#    ...
#    [113.27825 ]
#    [112.907394]
#    [112.74588 ]]]
#
#
#  [[[108.61515 ]
#    [108.048515]
#    [108.10411 ]
#    ...
#    [109.81935 ]
#    [109.78761 ]
#    [109.51147 ]]
#
#   [[110.01461 ]
#    [110.34228 ]
#    [109.41923 ]
#    ...
#    [112.125534]
#    [111.977905]
#    [110.511406]]
#
#   [[107.88899 ]
#    [108.11155 ]
#    [105.599236]
#    ...
#    [108.79821 ]
#    [109.93309 ]
#    [110.00327 ]]
#
#   [[110.31483 ]
#    [109.58415 ]
#    [109.62151 ]
#    ...
#    [111.377426]
#    [111.4444  ]
#    [111.457886]]]
#
#
#  ...
#
#
#  [[[109.55333 ]
#    [108.61515 ]
#    [107.43837 ]
#    ...
#    [ 98.141525]
#    [109.81935 ]
#    [109.23435 ]]
#
#   [[111.220184]
#    [110.01461 ]
#    [109.953026]
#    ...
#    [ 99.32967 ]
#    [112.125534]
#    [111.176285]]
#
#   [[108.10872 ]
#    [107.88899 ]
#    [107.68445 ]
#    ...
#    [ 96.729996]
#    [108.79821 ]
#    [110.5351  ]]
#
#   [[109.78523 ]
#    [110.31483 ]
#    [109.368805]
#    ...
#    [ 98.28484 ]
#    [111.377426]
#    [110.89219 ]]]
#
#
#  [[[108.42313 ]
#    [110.43457 ]
#    [108.19493 ]
#    ...
#    [109.31486 ]
#    [112.60812 ]
#    [110.40778 ]]
#
#   [[110.53713 ]
#    [112.49111 ]
#    [111.23985 ]
#    ...
#    [111.40595 ]
#    [114.45351 ]
#    [112.7744  ]]
#
#   [[109.6425  ]
#    [109.67281 ]
#    [108.869   ]
#    ...
#    [108.579254]
#    [111.363785]
#    [109.08674 ]]
#
#   [[110.0127  ]
#    [111.620056]
#    [108.80379 ]
#    ...
#    [110.81826 ]
#    [113.61972 ]
#    [111.8425  ]]]
#
#
#  [[[109.49424 ]
#    [108.70496 ]
#    [110.94468 ]
#    ...
#    [114.87967 ]
#    [108.99906 ]
#    [110.78313 ]]
#
#   [[111.519745]
#    [111.08683 ]
#    [112.45893 ]
#    ...
#    [115.66507 ]
#    [111.1503  ]
#    [113.084305]]
#
#   [[109.40595 ]
#    [108.72239 ]
#    [108.30647 ]
#    ...
#    [112.81254 ]
#    [109.49712 ]
#    [108.9775  ]]
#
#   [[111.21165 ]
#    [110.0974  ]
#    [111.50581 ]
#    ...
#    [115.40652 ]
#    [110.47575 ]
#    [112.04021 ]]]]

# %% [markdown]
# # Prediction on the test set

# %%
#evaluate on validatio datat 

_ = model.evaluate(Val_Dataset)

# %% [markdown]
# **predict using TTA (test time augmentations)**
#
#     We will basically use the same augmentations used in training, and predict multiple times on the test set. This will smoothen out the error in prediction

# %%
def TTA_prediction(model,  # trained model 
                   test_dataset, # should have augmentation (random)
                   num_repeats): # num of repreats 
    preds = []
    
    for _ in tqdm(iterable = range(num_repeats),desc='Prediction Number'):
        pred = model.predict(test_dataset)
        
        preds.append(pred)
        
    
    preds = np.array(preds)
    
    return preds


def mean_preds(predictions,axis=0):
    
    return predictions.mean(axis=axis).T.squeeze(axis=0)

def median_preds(predictions,axis=0):
    
    return np.median(predictions,axis=axis).T.squeeze(axis=0)



preds = TTA_prediction(model=model,
                      test_dataset = Test_Dataset,
                      num_repeats= 10)


#mean of predictions
mean_pred_val = pd.DataFrame(mean_preds(preds),
                            columns =['P', 'K', 'Mg', 'pH'] )


# median of predictions
med_pred_val = pd.DataFrame(median_preds(preds),
                             columns =['P', 'K', 'Mg', 'pH'])

# %% [markdown]
# # Distribution of predictions

# %%
plt.figure(figsize=(20,10))
plt.yticks(fontsize=16)
sns.distplot(a = mean_pred_val['P'],bins = 100,color = 'g',label='mean')
sns.distplot(a = med_pred_val['P'],bins = 100,color = 'b',label='median')

plt.title("Distribution of Phosphorours",
          font="Serif", 
          size=20,
          color='k')
plt.ylabel('Phosphorous Concentration (test)')

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.yticks(fontsize=16)
sns.distplot(a = mean_pred_val['K'],bins = 100,color = 'g',label='mean')
sns.distplot(a = med_pred_val['K'],bins = 100,color = 'b',label='median')

plt.title("Distribution of Pottasium",
          font="Serif", 
          size=20,
          color='k')
plt.ylabel('Pottasium Concentration (test)')

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.yticks(fontsize=16)
sns.distplot(a = mean_pred_val['Mg'],bins = 100,color = 'g',label='mean')
sns.distplot(a = med_pred_val['Mg'],bins = 100,color = 'b',label='median')

plt.title("Distribution of Magnesium",
          font="Serif", 
          size=20,
          color='k')
plt.ylabel('Magnesium Concentration (test)')

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.yticks(fontsize=16)
sns.distplot(a = mean_pred_val['pH'],bins = 30,color = 'g',label='mean')
sns.distplot(a = med_pred_val['pH'],bins = 30,color = 'b',label='median')

plt.title("Distribution of PH values",
          font="Serif", 
          size=20,
          color='k')
plt.ylabel(' PH values (test)')

plt.show()

# %% [markdown]
# # Submission

# %%
mean_pred_val.to_csv("pred_mean.csv",index_label="sample_index")

# !zip mean_sub.zip pred_mean.csv
# !rm pred_mean.csv

# %%
med_pred_val.to_csv("pred_med.csv",index_label="sample_index")

# !zip med_sub.zip pred_med.csv
# !rm pred_med.csv

# %%
# !ls
